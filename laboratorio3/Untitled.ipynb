# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

M=100000
N=100                 
L=int(M/N)            
x = np.arange(N)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

C_dir, err_C_dir = np.loadtxt("C:/Users/marti/lab1/laboratorio3/es03.1/sum_prog_C.txt", usecols=(0,1), delimiter=' ', unpack='true')
plt.errorbar(x,C_dir ,yerr=err_C_dir, label="C ")

P_dir, err_P_dir = np.loadtxt("C:/Users/marti/lab1/laboratorio3/es03.1/sum_prog_P.txt", usecols=(0,1), delimiter=' ', unpack='true')
plt.errorbar(x,P_dir ,yerr=err_P_dir, label="P ")
#plt.errorbar(x,gofr+0.2,yerr=err,errorevery=2,capsize=4,marker='s',mfc='red',mec='green', ms=5, mew=1)
plt.xlabel('throws')
plt.ylabel('price')
plt.title('P and C by sampling directly the final asset price for a GMB')
plt.legend()

plt.show()

# %%
C_dir, err_C_dir = np.loadtxt("C:/Users/marti/lab1/laboratorio3/es03.1/sum_prog_Cdiscr.txt", usecols=(0,1), delimiter=' ', unpack='true')
plt.errorbar(x,C_dir ,yerr=err_C_dir, label="C ")

P_dir, err_P_dir = np.loadtxt("C:/Users/marti/lab1/laboratorio3/es03.1/sum_prog_Pdiscr.txt", usecols=(0,1), delimiter=' ', unpack='true')
plt.errorbar(x,P_dir ,yerr=err_P_dir, label="P ")
#plt.errorbar(x,gofr+0.2,yerr=err,errorevery=2,capsize=4,marker='s',mfc='red',mec='green', ms=5, mew=1)
plt.xlabel('throws')
plt.ylabel('price')
plt.title('P and C by sampling the discretized GMB path of the asset price')
plt.legend()

plt.show()
