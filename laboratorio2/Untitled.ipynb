# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

M=100000
N=100                 
L=int(M/N)            
x = np.arange(N) 
err_prog=np.zeros(N)
sum_prog=np.zeros(N)

file_sum = open("C:/Users/marti/lab1/laboratorio1/es1/sum_prog.txt", "r")
i=0
for line in file_sum:
    sum_prog[i]=float(line)
    #print(sum_prog[i])
    i+=1
    
file_sum.close()
i=0
file_err = open("C:/Users/marti/lab1/laboratorio1/es1/err_prog.txt", "r")
for line in file_err:
    err_prog[i]=float(line)
    i+=1

file_err.close()  
x*=L # Number of throws = block * (Number of throws in each block)
plt.errorbar(x,sum_prog-0.5,yerr=err_prog)

plt.xlabel('#throws')
plt.ylabel('<r>-1/2')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     251         try:
# --> 252             report = subprocess.check_output(
#     253                 command, cwd=cwd if cwd is not None else self.texcache,
#
# ~\anaconda3\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     423
# --> 424     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     425                **kwargs).stdout
#
# ~\anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     527         if check and retcode:
# --> 528             raise CalledProcessError(retcode, process.args,
#     529                                      output=stdout, stderr=stderr)
#
# ...
