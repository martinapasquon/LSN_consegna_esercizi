# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

M=100000
N=100                 
L=int(M/N)            
x = np.arange(N)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

sum, err = np.loadtxt("C:/Users/marti/lab1/laboratorio1/prova/sum_prog.txt", usecols=(0,1), delimiter=' ', unpack='true')
plt.errorbar(x,sum ,yerr=err)
plt.xlabel('throws')
plt.ylabel('<n>')
plt.title('estimation of <r>')

plt.show()

# %%
#plt.ylabel('<(r-0.5)^2>-1/12')

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

sum, err = np.loadtxt("C:/Users/marti/lab1/laboratorio1/es2/sum_prog.txt", usecols=(0,1), delimiter=' ', unpack='true')
plt.errorbar(x,sum ,yerr=err)
plt.xlabel('throws')
plt.ylabel('')


plt.show()

# %%
n_bins = 50
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

chi_quadro = np.loadtxt("C:/Users/marti/lab1/laboratorio1/es3/chi_quadro.txt", unpack='true')
plt.hist(chi_quadro, n_bins, density=True, facecolor='g', range=(40, 60))
plt.xlabel('throws')
plt.ylabel('')


plt.show()

# %%
n_bins = 50
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

gauss = np.loadtxt("C:/Users/marti/lab1/laboratorio1/es01.2/gauss.txt", unpack='true')
plt.hist(gauss, n_bins, density=True, facecolor='g', range=(40, 60))
plt.xlabel('throws')
plt.ylabel('')


plt.show()
# Out:
# C:\Users\marti\anaconda3\lib\site-packages\numpy\lib\histograms.py:905: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
M=10000
gauss=np.zeros(M)
gauss1=np.zeros(M)
gauss2=np.zeros(M)
gauss3=np.zeros(M)
n_bins = 50

file_gauss = open("C:/Users/marti/lab1/laboratorio1/es01.2/gauss.txt", "r")
i=0
for line in file_gauss:
    gauss[i]=float(line)
    i+=1
    
file_gauss.close()
plt.xlabel('gauss')
plt.ylabel("n")
plt.title('strandard distribution')
n, bins, patches = plt.hist(gauss, n_bins, density=True, facecolor='g', range=(-4,4))
plt.grid(True)
plt.show()



file_gauss1 = open("C:/Users/marti/lab1/laboratorio1/es01.2/gauss1.txt", "r")
i=0
for line in file_gauss1:
    gauss1[i]=float(line)
    i+=1
file_gauss1.close()
plt.xlabel('gauss')
plt.ylabel("n ")
plt.title('strandard distribution, N=2')
n, bins, patches = plt.hist(gauss1, n_bins, density=True, facecolor='g', range=(-4,4))
plt.grid(True)
plt.show()



file_gauss2 = open("C:/Users/marti/lab1/laboratorio1/es01.2/gauss2.txt", "r")
i=0
for line in file_gauss2:
    gauss2[i]=float(line)
    i+=1
file_gauss2.close()
plt.xlabel('gauss')
plt.ylabel("n")
plt.title('strandard distribution, N=10')
n, bins, patches = plt.hist(gauss2, n_bins, density=True, facecolor='g', range=(-4,4))
plt.grid(True)
plt.show()


file_gauss3 = open("C:/Users/marti/lab1/laboratorio1/es01.2/gauss3.txt", "r")
i=0
for line in file_gauss3:
    gauss3[i]=float(line)
    i+=1
file_gauss3.close()
plt.xlabel('gauss')
plt.ylabel("n ")
plt.title('strandard distribution, N=100')
n, bins, patches = plt.hist(gauss3, n_bins, density=True, facecolor='g', range=(-4,4))
plt.grid(True)
plt.show()

# %%
M=10000
exp=np.zeros(M)
exp1=np.zeros(M)
exp2=np.zeros(M)
exp3=np.zeros(M)
n_bins = 50

file_exp = open("C:/Users/marti/lab1/laboratorio1/es01.2/exp.txt", "r")
i=0
for line in file_exp:
    exp[i]=float(line)
    i+=1
    
file_exp.close()
plt.xlabel('exp')
plt.ylabel("n")
plt.title('exponential distribution, N=1')
n, bins, patches = plt.hist(exp, n_bins, density=True, facecolor='g', range=(0, 8))
plt.grid(True)
plt.show()

file_exp1 = open("C:/Users/marti/lab1/laboratorio1/es01.2/exp1.txt", "r")
i=0
for line in file_exp1:
    exp1[i]=float(line)
    i+=1
    
file_exp1.close()
plt.xlabel('exp')
plt.ylabel("n")
plt.title('exponential distribution, N=2')
n, bins, patches = plt.hist(exp1, n_bins, density=True, facecolor='g', range=(0, 8))
plt.grid(True)
plt.show()


file_exp2 = open("C:/Users/marti/lab1/laboratorio1/es01.2/exp2.txt", "r")
i=0
for line in file_exp2:
    exp2[i]=float(line)
    i+=1
    
file_exp2.close()
plt.xlabel('exp')
plt.ylabel("n")
plt.title('exponential distribution, N=10')
n, bins, patches = plt.hist(exp2, n_bins, density=True, facecolor='g', range=(0, 8))
plt.grid(True)
plt.show()


file_exp3 = open("C:/Users/marti/lab1/laboratorio1/es01.2/exp3.txt", "r")
i=0
for line in file_exp3:
    exp3[i]=float(line)
    i+=1
    
file_exp3.close()
plt.xlabel('exp')
plt.ylabel("n")
plt.title('exponential distribution, N=100')
n, bins, patches = plt.hist(exp3, n_bins, density=True, facecolor='g', range=(0, 8))
plt.grid(True)
plt.show()

# %%
M=10000
lorentz=np.zeros(M)
lorentz1=np.zeros(M)
lorentz2=np.zeros(M)
lorentz3=np.zeros(M)
n_bins = 50

file_lorentz = open("C:/Users/marti/lab1/laboratorio1/es01.2/Lorentz.txt", "r")
i=0
for line in file_lorentz:
    lorentz[i]=float(line)
    i+=1
    
file_lorentz.close()
plt.xlabel('Lorentz')
plt.ylabel("n")
plt.title('Cauchy-Lorentz distribution, N=1 ')
n, bins, patches = plt.hist(lorentz, n_bins, density=True, facecolor='g', range=(-10,10))
plt.grid(True)
plt.show()





file_lorentz1 = open("C:/Users/marti/lab1/laboratorio1/es01.2/Lorentz1.txt", "r")
i=0
for line in file_lorentz1:
    lorentz1[i]=float(line)
    i+=1
    
file_lorentz1.close()
plt.xlabel('Lorentz')
plt.ylabel("n")
plt.title('Cauchy-Lorentz distribution, N=2  ')
n, bins, patches = plt.hist(lorentz1, n_bins, density=True, facecolor='g', range=(-10,10))
plt.grid(True)
plt.show()



file_lorentz2 = open("C:/Users/marti/lab1/laboratorio1/es01.2/Lorentz2.txt", "r")
i=0
for line in file_lorentz2:
    lorentz2[i]=float(line)
    i+=1
    
file_lorentz2.close()
plt.xlabel('Lorentz')
plt.ylabel("n")
plt.title('Cauchy-Lorentz distribution, N=10  ')
n, bins, patches = plt.hist(lorentz2, n_bins, density=True, facecolor='g', range=(-10,10))
plt.grid(True)
plt.show()



file_lorentz3 = open("C:/Users/marti/lab1/laboratorio1/es01.2/Lorentz3.txt", "r")
i=0
for line in file_lorentz3:
    lorentz3[i]=float(line)
    i+=1
    
file_lorentz3.close()
plt.xlabel('Lorentz')
plt.ylabel("n")
plt.title('Cauchy-Lorentz distribution, N=100')
n, bins, patches = plt.hist(lorentz3, n_bins, density=True, facecolor='g', range=(-10,10))
plt.grid(True)

plt.show()

# %%
x = np.arange(N)  
M=10000
N=100
L=int(M/N)    
err_Buffon=np.zeros(N)
sum_Buffon=np.zeros(N)

file_Buffon = open("C:/Users/marti/lab1/laboratorio1/es01.3/sum_prog.txt", "r")
i=0
for line in file_Buffon:
    sum_Buffon[i]=float(line)
    #print(sum_prog[i])
    i+=1
    
file_Buffon.close()
i=0
file_errBuffon = open("C:/Users/marti/lab1/laboratorio1/es01.3/err_prog.txt", "r")
for line in file_errBuffon:
    err_Buffon[i]=float(line)
    i+=1

file_errBuffon.close()  
x*=L
plt.errorbar(x,sum_Buffon,yerr=err_Buffon)
plt.xlabel('number of throws')
plt.ylabel('pi greco')
plt.grid(True)
plt.show()
