# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
#grafico della Temperatura che oscilla, 5000 blocchi da 1. Per Solidi. T iniziale=0.7

             
          
x = np.arange(2000)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ene, errs= np.loadtxt("C:output.ene.o", usecols=(2,3), unpack='true')
plt.errorbar(x,ene ,yerr=errs, label="solid")
#liquid, errl= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_temp_oscill_liquid.txt", usecols=(2,3), unpack='true')
#plt.errorbar(x,liquid ,yerr=errl, label="liquid")
#gas, errg= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_temp_oscill_gas.txt", usecols=(2,3), unpack='true')
#plt.errorbar(x,gas ,yerr=errg, label="gas")


plt.xlabel('number of blocks')
plt.ylabel('Temperature')
plt.title('Temperature')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10860/4198568595.py in <module>
#      12 plt.rc('font', family='serif')
#      13
# ---> 14 ene, errs= np.loadtxt("C:output.ene.o", usecols=(2,3), unpack='true')
#      15 plt.errorbar(x,ene ,yerr=errs, label="solid")
#      16 #liquid, errl= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_temp_oscill_liquid.txt", usecols=(2,3), unpack='true')
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1063             fname = os_fspath(fname)
#    1064         if _is_string_like(fname):
# -> 1065             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1066             fencoding = getattr(fh, 'encoding', 'latin1')
# ...

# %%
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

x = np.arange(20)

solidT, errsT= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_temp_solid.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,solidT ,yerr=errsT, label="solid")
liquidT, errlT= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_temp_liquid.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,liquidT ,yerr=errlT, label="liquid")
gasT, errgT= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_temp_gas.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,gasT ,yerr=errgT, label="gas")

plt.xlabel('number of blocks')
plt.ylabel('Temperature ')
plt.title('progressive average values and uncertainties of temperature')
plt.legend()

plt.show()

# %%
solidEtot, errsEtot= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_etot_solid.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,solidEtot ,yerr= errsEtot, label="solid")
liquidEtot,  errlEtot= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_etot_liquid.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,liquidEtot ,yerr= errlEtot, label="liquid")
gasEtot,  errgEtot= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_etot_gas.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,gasEtot ,yerr= errgEtot, label="gas")

plt.xlabel('number of blocks')
plt.ylabel('total internal energy per particle')
plt.title(' total internal energy per particle progressive average values and uncertainties of total internal energy per particle')
plt.legend()
plt.grid(True)

plt.show()

# %%
solidK, errsK= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_ekin_solid.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,solidK ,yerr= errsK, label="solid")
liquidK,  errlK= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_ekin_liquid.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,liquidK ,yerr= errlK, label="liquid")
gasK,  errgK= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_ekin_gas.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,gasK ,yerr= errgK, label="gas")

plt.xlabel('number of blocks')
plt.ylabel(' kinetic energy per particle')
plt.title('progressive average values and uncertainties of kinetic energy per particle')
plt.legend()
plt.grid(True)

plt.show()

# %%
solidu, errsu= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_epot_solid.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,solidu ,yerr=errsu, label="solid")
liquidu, errlu= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_epot_liquid.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,liquidu ,yerr=errlu, label="liquid")
gasu, errgu= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_epot_gas.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,gasu ,yerr=errgu, label="gas")

plt.xlabel('number of blocks')
plt.ylabel('progressive average values and uncertainties of potential energy per particle')
plt.title('potential energy per particle')
plt.legend()
plt.grid(True)

plt.show()

# %%
solidp, errsp= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_ptot_solid.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,solidp ,yerr=errsp, label="solid")
liquidp, errlp= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_ptot_liquid.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,liquidp ,yerr=errlp, label="liquid")
gasp, errgp= np.loadtxt("C:/Users/marti/lab1/laboratorio4/MDNVE_MCNVT/output_ptot_gas.txt", usecols=(2,3), unpack='true')
plt.errorbar(x,gasp ,yerr=errgp, label="gas")

plt.xlabel('number of blocks')
plt.ylabel('progressive average values and uncertainties of pressure')
plt.title('pressure')
plt.legend()
plt.grid(True)

plt.show()
